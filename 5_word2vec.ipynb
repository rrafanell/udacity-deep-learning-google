# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  #Finds the most common words in the words vector -> "[['UNK', -1], ('the', 1061396), ('of', 593677), ...]"
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    # Builds a word -> position map: (UNK,1), (the,2), (of,3)
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))

num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.727555
# Nearest to at: relapse, merseburg, lothal, characteristic, vic, cancelling, cultivars, tricked,
# Nearest to other: gorey, ceiling, vinny, subcode, mankind, capitan, scratching, baka,
# Nearest to one: plotline, godel, mortar, diverse, pole, adrianople, intron, shelby,
# Nearest to all: dixieland, democide, arid, guiding, havilland, khattab, rodan, gein,
# Nearest to states: pseudo, wilder, ficino, entered, dec, confiscated, brubeck, explicated,
# Nearest to can: deceive, astronomical, broadsword, befell, tatian, nicopolis, zola, dedicating,
# Nearest to the: intensely, catullus, tax, urban, invocation, cubical, final, penises,
# Nearest to over: boar, tienne, enix, peyton, allocated, rags, creating, merging,
# Nearest to into: flutist, reclamation, harrisburg, intuition, surge, myself, albers, immemorial,
# Nearest to while: unnecessary, mulder, thinly, xxiii, egypt, identification, approved, debatable,
# Nearest to used: anoa, greenwich, iphigenia, brock, frontman, stags, provisioning, telephony,
# Nearest to after: hadassah, ashland, relieves, ning, chants, april, tito, isotropic,
# Nearest to in: speedup, respectful, swung, scorpion, diagnose, segmentation, crucible, dormancy,
# Nearest to some: big, solvent, euros, supplanting, filmmaker, schwarzschild, mst, astronauts,
# Nearest to this: benchmark, wilder, powers, tritone, financiers, rcs, answering, nymphs,
# Nearest to seven: cassiopeia, herc, definite, bouvet, freeh, awk, rumi, bannockburn,
# Average loss at step 2000: 4.366210
# Average loss at step 4000: 3.868995
# Average loss at step 6000: 3.792302
# Average loss at step 8000: 3.688400
# Average loss at step 10000: 3.615128
# Nearest to at: in, previous, cancelling, on, tricked, automaker, promote, relapse,
# Nearest to other: gorey, viterbo, mathematics, subgenius, capitan, pacified, disavowed, distract,
# Nearest to one: two, three, four, eight, six, shelby, seven, mariani,
# Nearest to all: occured, pests, ponens, algonquian, every, chianti, compulsive, enclosure,
# Nearest to states: entered, ficino, pseudo, secular, ztt, heyday, senex, warming,
# Nearest to can: may, could, would, will, dedicating, tatian, zola, kobe,
# Nearest to the: a, its, this, his, their, each, elaborates, alb,
# Nearest to over: distress, boar, creating, associations, jaeger, ye, vii, ux,
# Nearest to into: from, norma, inen, asparagus, fermi, after, to, sophist,
# Nearest to while: before, nut, warm, egypt, consults, and, guerra, southwards,
# Nearest to used: parables, tandy, called, dou, ang, xico, stags, iphigenia,
# Nearest to after: ning, interpol, relieves, retracted, in, hayling, ashland, chants,
# Nearest to in: of, at, during, on, with, from, grazing, after,
# Nearest to some: many, senegal, its, tyrosine, instantiation, podium, prostaglandin, astronauts,
# Nearest to this: it, the, partito, zappa, contribution, which, benchmark, sushi,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Average loss at step 12000: 3.607874
# Average loss at step 14000: 3.572649
# Average loss at step 16000: 3.407527
# Average loss at step 18000: 3.456873
# Average loss at step 20000: 3.541204
# Nearest to at: in, from, on, during, merseburg, canadian, gerald, chaotic,
# Nearest to other: many, some, mathematics, subgenius, these, gorey, contribute, pacified,
# Nearest to one: four, two, seven, three, six, eight, nine, five,
# Nearest to all: some, many, these, ponens, every, pests, algonquian, each,
# Nearest to states: ztt, entered, warming, leftism, pseudo, ficino, amaranth, reactions,
# Nearest to can: may, would, could, will, should, must, cannot, might,
# Nearest to the: its, their, his, a, this, elaborates, fixture, an,
# Nearest to over: associations, distress, pendergast, vii, creating, theoretical, vivian, ux,
# Nearest to into: from, by, after, norma, albers, inen, annibale, casinos,
# Nearest to while: before, nut, warm, after, universal, where, mammalian, fabricius,
# Nearest to used: described, parables, known, called, found, rhetoric, tandy, adjective,
# Nearest to after: before, ning, from, when, into, retracted, interpol, during,
# Nearest to in: at, on, with, from, between, during, memel, tomato,
# Nearest to some: many, these, several, all, their, senegal, other, most,
# Nearest to this: it, which, the, each, that, benchmark, sushi, potentially,
# Nearest to seven: eight, six, nine, three, five, four, two, one,
# Average loss at step 22000: 3.502555
# Average loss at step 24000: 3.490639
# Average loss at step 26000: 3.482331
# Average loss at step 28000: 3.477746
# Average loss at step 30000: 3.501340
# Nearest to at: in, during, near, on, merseburg, before, under, subregion,
# Nearest to other: subgenius, these, mathematics, many, equinox, different, stadiums, such,
# Nearest to one: two, seven, four, three, eight, nine, five, six,
# Nearest to all: some, these, many, each, both, every, compulsive, owned,
# Nearest to states: kingdom, senex, ztt, entered, ficino, amaranth, nations, leftism,
# Nearest to can: may, could, will, would, should, must, cannot, might,
# Nearest to the: its, their, his, some, a, bigger, elaborates, chatter,
# Nearest to over: associations, distress, jaeger, creating, theoretical, cigarette, peyton, husband,
# Nearest to into: from, after, norma, annibale, on, sceptical, out, under,
# Nearest to while: before, but, where, nut, mammalian, when, however, although,
# Nearest to used: known, found, called, responsible, tandy, parables, described, appears,
# Nearest to after: before, when, during, ning, from, relieves, into, summoning,
# Nearest to in: during, at, on, of, between, from, vauxhall, under,
# Nearest to some: many, these, all, several, their, most, senegal, various,
# Nearest to this: which, it, what, any, bert, his, no, some,
# Nearest to seven: nine, four, five, six, eight, three, zero, one,
# Average loss at step 32000: 3.502227
# Average loss at step 34000: 3.495971
# Average loss at step 36000: 3.451837
# Average loss at step 38000: 3.299842
# Average loss at step 40000: 3.429118
# Nearest to at: during, on, in, before, near, airwaves, previous, transliteration,
# Nearest to other: various, different, some, ljubljana, bearings, including, many, belles,
# Nearest to one: seven, six, eight, four, two, five, three, nine,
# Nearest to all: these, both, some, each, gerard, two, jeanneret, many,
# Nearest to states: kingdom, nations, senex, matthias, ficino, ztt, state, warming,
# Nearest to can: may, will, could, would, should, must, might, cannot,
# Nearest to the: their, its, this, another, his, each, any, a,
# Nearest to over: associations, through, days, oh, thane, theoretical, creating, biscuits,
# Nearest to into: from, through, norma, out, albers, inen, establishes, against,
# Nearest to while: before, where, when, although, after, though, nut, southwards,
# Nearest to used: found, known, responsible, referred, described, called, possible, able,
# Nearest to after: before, when, during, ning, while, summoning, from, ashland,
# Nearest to in: during, at, for, near, from, under, hydroxyl, of,
# Nearest to some: many, these, several, all, various, most, certain, their,
# Nearest to this: which, that, it, the, any, potentially, what, he,
# Nearest to seven: eight, six, nine, five, three, four, zero, two,
# Average loss at step 42000: 3.436889
# Average loss at step 44000: 3.451792
# Average loss at step 46000: 3.450029
# Average loss at step 48000: 3.348560
# Average loss at step 50000: 3.382075
# Nearest to at: during, under, in, near, merseburg, forge, on, ho,
# Nearest to other: various, different, sherpa, some, many, these, attribute, subgenius,
# Nearest to one: two, six, eight, four, seven, three, five, nine,
# Nearest to all: some, each, both, these, every, many, only, goa,
# Nearest to states: kingdom, nations, matthias, senex, state, forces, surfing, amaranth,
# Nearest to can: will, may, could, would, must, should, might, cannot,
# Nearest to the: its, their, his, this, a, any, competency, eccles,
# Nearest to over: through, associations, mir, irregularly, away, punchline, thane, kindred,
# Nearest to into: from, through, under, norma, inen, publ, annibale, after,
# Nearest to while: before, when, where, although, after, however, though, but,
# Nearest to used: known, found, responsible, referred, described, designed, able, possible,
# Nearest to after: before, when, during, while, ning, summoning, gave, feels,
# Nearest to in: during, from, on, of, at, under, between, vauxhall,
# Nearest to some: many, several, these, various, most, those, all, both,
# Nearest to this: it, which, he, the, there, that, mandatory, unworkable,
# Nearest to seven: six, eight, nine, three, four, five, zero, two,
# Average loss at step 52000: 3.438457
# Average loss at step 54000: 3.426364
# Average loss at step 56000: 3.439398
# Average loss at step 58000: 3.400303
# Average loss at step 60000: 3.391747
# Nearest to at: in, near, during, under, subregion, before, unfounded, crematoria,
# Nearest to other: various, different, many, some, more, sherpa, stadiums, subgenius,
# Nearest to one: two, eight, seven, four, six, nine, five, three,
# Nearest to all: each, every, some, many, these, both, various, those,
# Nearest to states: kingdom, nations, forces, matthias, senex, countries, ancillary, state,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to the: a, its, their, some, each, this, any, his,
# Nearest to over: through, associations, mir, irregularly, about, away, theoretical, leipzig,
# Nearest to into: through, from, norma, under, out, inen, publ, albers,
# Nearest to while: although, before, when, though, where, after, however, like,
# Nearest to used: known, responsible, designed, found, referred, described, held, able,
# Nearest to after: before, when, during, while, ning, following, gave, feels,
# Nearest to in: during, within, of, at, among, near, including, since,
# Nearest to some: many, several, these, various, most, those, different, all,
# Nearest to this: which, it, that, the, there, what, potentially, some,
# Nearest to seven: eight, six, five, nine, four, three, one, zero,
# Average loss at step 62000: 3.236924
# Average loss at step 64000: 3.257011
# Average loss at step 66000: 3.398896
# Average loss at step 68000: 3.395978
# Average loss at step 70000: 3.362516
# Nearest to at: during, before, astrometry, under, merseburg, saline, on, rye,
# Nearest to other: various, different, some, sherpa, bioinformatics, many, more, including,
# Nearest to one: two, seven, six, four, eight, nine, three, five,
# Nearest to all: some, many, various, each, every, both, these, any,
# Nearest to states: kingdom, nations, state, countries, matthias, ancillary, senex, forces,
# Nearest to can: could, may, would, will, might, should, must, cannot,
# Nearest to the: its, their, a, this, any, each, our, these,
# Nearest to over: through, about, mir, thane, caching, associations, pendergast, irregularly,
# Nearest to into: through, from, under, inen, within, norma, publ, out,
# Nearest to while: although, before, where, though, when, however, including, like,
# Nearest to used: known, responsible, referred, seen, found, designed, described, cited,
# Nearest to after: before, during, when, ning, while, if, summoning, gave,
# Nearest to in: within, during, on, from, among, for, between, through,
# Nearest to some: many, several, these, all, various, most, their, certain,
# Nearest to this: it, which, the, that, another, some, what, there,
# Nearest to seven: six, eight, nine, four, five, three, two, one,
# Average loss at step 72000: 3.375803
# Average loss at step 74000: 3.349163
# Average loss at step 76000: 3.317408
# Average loss at step 78000: 3.352755
# Average loss at step 80000: 3.377467
# Nearest to at: in, repressed, during, merseburg, zimmerman, on, astrometry, previous,
# Nearest to other: various, sherpa, different, bioinformatics, including, stadiums, belles, others,
# Nearest to one: seven, two, six, eight, four, three, five, nine,
# Nearest to all: various, both, every, many, some, these, each, collie,
# Nearest to states: kingdom, nations, state, senex, matthias, menai, countries, forces,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to the: its, their, a, this, elaborates, exterminating, our, affreightment,
# Nearest to over: through, between, about, kindred, hinds, mir, safeguarded, into,
# Nearest to into: through, from, within, inen, under, off, shortfalls, sceptical,
# Nearest to while: although, though, before, when, after, however, but, where,
# Nearest to used: known, referred, responsible, seen, designed, described, available, written,
# Nearest to after: before, during, when, while, ning, without, following, later,
# Nearest to in: during, on, within, at, between, since, until, around,
# Nearest to some: many, several, various, most, certain, these, all, any,
# Nearest to this: it, which, what, there, the, freenet, mandatory, that,
# Nearest to seven: six, eight, five, four, nine, three, one, two,
# Average loss at step 82000: 3.407900
# Average loss at step 84000: 3.411219
# Average loss at step 86000: 3.392283
# Average loss at step 88000: 3.353472
# Average loss at step 90000: 3.366562
# Nearest to at: in, near, during, on, astrometry, under, university, subnet,
# Nearest to other: various, sherpa, belles, stadiums, hypothesized, effecting, magical, bioinformatics,
# Nearest to one: seven, two, four, eight, six, three, five, nine,
# Nearest to all: many, both, various, every, some, several, collie, each,
# Nearest to states: kingdom, nations, state, us, senex, provinces, countries, menai,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to the: its, this, a, their, his, any, crucifixes, peas,
# Nearest to over: through, about, between, within, off, kindred, trasimene, across,
# Nearest to into: through, from, within, inen, publ, sceptical, out, immemorial,
# Nearest to while: although, when, though, before, after, were, but, where,
# Nearest to used: known, referred, designed, responsible, seen, described, able, presented,
# Nearest to after: before, when, during, while, ning, upon, for, until,
# Nearest to in: during, within, at, under, near, with, on, of,
# Nearest to some: many, several, these, certain, various, most, those, all,
# Nearest to this: it, which, the, some, another, freenet, what, consisting,
# Nearest to seven: eight, six, nine, four, five, three, zero, one,
# Average loss at step 92000: 3.396917
# Average loss at step 94000: 3.255824
# Average loss at step 96000: 3.358569
# Average loss at step 98000: 3.239291
# Average loss at step 100000: 3.358009
# Nearest to at: during, in, near, on, repressed, after, astrometry, merseburg,
# Nearest to other: various, hypothesized, stadiums, others, sherpa, jamil, individual, different,
# Nearest to one: two, four, eight, seven, nine, three, five, six,
# Nearest to all: many, every, various, these, several, both, some, any,
# Nearest to states: kingdom, nations, us, state, forces, senex, lest, matthias,
# Nearest to can: may, could, will, should, must, cannot, would, might,
# Nearest to the: his, their, its, your, elaborates, a, our, each,
# Nearest to over: through, between, kindred, within, about, additional, caffeine, theoretical,
# Nearest to into: through, within, from, off, in, out, inen, publ,
# Nearest to while: although, when, though, before, but, where, after, however,
# Nearest to used: referred, responsible, designed, known, presented, spoken, available, able,
# Nearest to after: before, during, when, while, without, ning, although, following,
# Nearest to in: during, within, on, throughout, at, until, from, of,
# Nearest to some: many, several, these, certain, any, those, various, all,
# Nearest to this: which, it, another, what, he, the, itself, inker,
# Nearest to seven: eight, six, nine, four, five, three, two, zero,

# %%
num_points = 400
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index
    assert skip_window%2==1
 
    span = 2 * skip_window + 1 # [ skip_window target skip_window ] -> window size
 
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32) #array of [left, target, right ] -> [ left, right ]
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)# array of [target]
    
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side
 
    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)
 
    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer 
        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            print("batch["+str(i)+","+str(col_idx)+"] = buffer["+str(j)+"]")
            col_idx += 1
        labels[i, 0] = buffer[target]
 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
#valid_examples = np.array(random.sample(range(valid_window), valid_size))

num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Model.
  # Look up embeddings for inputs.
  embeds = None
  for i in range(2*skip_window):
        embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
        print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
        emb_x,emb_y = embedding_i.get_shape().as_list()
        if embeds is None:
            embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
        else:
            embeds = tf.concat([embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])],2)

  assert embeds.get_shape().as_list()[2]==2*skip_window
  print("Concat embedding size: %s"%embeds.get_shape().as_list())
  avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False)
  print("Avg embedding size: %s"%avg_embed.get_shape().as_list())

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embedding 0 shape: [128, 128]
# embedding 1 shape: [128, 128]
# Concat embedding size: [128, 128, 2]
# Avg embedding size: [128, 128]

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.570450
# Nearest to at: odyssey, austria, cornerstone, aquariums, suv, deconstructionist, principle, lighter,
# Nearest to other: migr, beheading, regionally, espace, kankan, surreptitiously, reading, bayard,
# Nearest to one: sidewalks, upon, carabineros, prophecy, sedative, taliban, rhazes, mercenary,
# Nearest to all: salvage, devotions, phonation, cheyenne, mickey, decadence, unter, nonnegative,
# Nearest to states: monopoly, madhava, concentrates, simplicity, synthesis, cosmology, festivities, quadrature,
# Nearest to can: concisely, bulb, stupidity, symptoms, curved, ulein, vlaamse, marion,
# Nearest to the: confidentiality, suspicious, ciboney, historicist, lawson, panthera, machinery, brushed,
# Nearest to over: soaps, diarist, miata, contacting, janos, previous, tilsit, flaw,
# Nearest to into: songwriter, stringing, dictionaries, referral, activator, ostia, steeple, hedwig,
# Nearest to while: lutes, succeeding, overlooked, relied, libel, dudley, narrated, vaguely,
# Nearest to used: liquid, informative, cannibal, iulius, rightness, dosing, vessel, exhibition,
# Nearest to after: yeomen, cale, phone, advisory, vanquish, corridor, cloned, korchnoi,
# Nearest to in: admirals, fore, quartic, modelled, mack, fur, exporting, endosperm,
# Nearest to some: sanctuaries, tr, tenures, cumbria, elephants, concerns, perestroika, psa,
# Nearest to this: marcuse, suppressor, richthofen, griese, noodle, nicknamed, sebastian, drilling,
# Nearest to seven: governmental, bfbs, campos, inquiry, resilience, carr, sident, octal,
# Average loss at step 2000: 4.041983
# Average loss at step 4000: 3.506712
# Average loss at step 6000: 3.349530
# Average loss at step 8000: 3.197598
# Average loss at step 10000: 3.147245
# Nearest to at: shooters, in, deirdre, gurdjieff, deconstructionist, engrailed, prejudiced, cornerstone,
# Nearest to other: beheading, espace, amalgam, regionally, important, some, directors, migr,
# Nearest to one: two, three, eight, four, six, nine, heinous, seven,
# Nearest to all: salvage, several, devotions, flash, nonnegative, uwe, cheyenne, llewelyn,
# Nearest to states: monopoly, fared, synthesis, madhava, sculptured, legends, australian, capetian,
# Nearest to can: could, may, would, will, might, concisely, nuclear, must,
# Nearest to the: its, their, a, this, his, alphabets, any, prim,
# Nearest to over: soaps, janos, auroral, following, today, through, subscriptions, previous,
# Nearest to into: from, oscillations, for, pamplona, spectre, dop, fruiting, demonstrating,
# Nearest to while: later, feudal, striking, suprema, relied, lutes, succeeding, dudley,
# Nearest to used: possess, iulius, rightness, lettre, known, heiress, cond, homage,
# Nearest to after: until, during, from, tagore, phone, amex, cale, corridor,
# Nearest to in: on, fore, at, between, around, endosperm, sassanid, admirals,
# Nearest to some: many, tr, other, interest, concerns, anglesey, vanish, their,
# Nearest to this: which, it, the, variably, sebastian, that, perpetuity, his,
# Nearest to seven: nine, eight, five, six, four, three, zero, two,
# Average loss at step 12000: 3.172580
# Average loss at step 14000: 3.131210
# Average loss at step 16000: 3.147683
# Average loss at step 18000: 3.104908
# Average loss at step 20000: 2.992034
# Nearest to at: shooters, in, suv, ite, shareholder, indexes, canard, reform,
# Nearest to other: espace, beheading, different, individual, directors, amalgam, regionally, whirl,
# Nearest to one: two, eight, seven, six, three, nine, felipe, four,
# Nearest to all: salvage, several, flash, devotions, veto, control, llewelyn, tanenbaum,
# Nearest to states: monopoly, synthesis, fared, bronzes, kingdom, sculptured, unsophisticated, madhava,
# Nearest to can: could, may, would, will, might, must, should, cannot,
# Nearest to the: a, its, their, his, any, ricardo, our, disguised,
# Nearest to over: auroral, janos, soaps, subscriptions, through, secundus, today, bankrupt,
# Nearest to into: from, oscillations, songwriter, between, pamplona, across, highwayman, accelerates,
# Nearest to while: when, later, striking, feudal, dudley, miscellaneous, but, rolls,
# Nearest to used: known, found, available, required, possess, cassation, possible, edible,
# Nearest to after: before, until, during, tagore, phone, amex, galleria, when,
# Nearest to in: modelled, fore, during, around, on, eratosthenes, at, throughout,
# Nearest to some: many, these, interest, their, any, several, anglesey, easterners,
# Nearest to this: which, it, that, variably, what, kennel, perpetuity, the,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Average loss at step 22000: 3.052793
# Average loss at step 24000: 3.023559
# Average loss at step 26000: 2.992081
# Average loss at step 28000: 3.010977
# Average loss at step 30000: 2.989695
# Nearest to at: shooters, in, sorceress, entrails, suv, during, shareholder, colonized,
# Nearest to other: various, different, individual, cultural, many, espace, some, whirl,
# Nearest to one: two, five, six, four, three, seven, nine, eight,
# Nearest to all: both, flash, several, these, many, any, salvage, devotions,
# Nearest to states: kingdom, monopoly, fared, countries, sculptured, rt, legends, nations,
# Nearest to can: may, could, would, will, might, must, should, cannot,
# Nearest to the: their, its, a, this, your, modes, our, any,
# Nearest to over: through, auroral, secundus, janos, subscriptions, within, soaps, bankrupt,
# Nearest to into: from, through, across, oscillations, between, cohort, songwriter, refrigerators,
# Nearest to while: when, although, brun, feudal, rolls, miscellaneous, zeitung, laozi,
# Nearest to used: known, available, required, found, held, possible, considered, called,
# Nearest to after: before, during, when, until, from, registrations, tagore, despite,
# Nearest to in: during, fore, on, throughout, around, at, modelled, within,
# Nearest to some: many, these, several, various, their, any, interest, both,
# Nearest to this: which, it, the, that, what, there, sebastian, clinching,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Average loss at step 32000: 2.843429
# Average loss at step 34000: 2.947289
# Average loss at step 36000: 2.935767
# Average loss at step 38000: 2.933089
# Average loss at step 40000: 2.924145
# Nearest to at: shooters, sorceress, entrails, in, during, engrailed, extending, isca,
# Nearest to other: various, individual, different, espace, cultural, some, amalgam, regionally,
# Nearest to one: two, seven, six, three, four, five, eight, veeck,
# Nearest to all: both, many, several, various, salvage, any, flash, every,
# Nearest to states: kingdom, countries, monopoly, nations, removes, legends, fared, bronzes,
# Nearest to can: may, could, would, will, might, must, should, cannot,
# Nearest to the: their, its, ricardo, your, his, our, a, modes,
# Nearest to over: through, auroral, secundus, within, subscriptions, soaps, bankrupt, pritchard,
# Nearest to into: from, through, across, efficacious, oscillations, accelerates, between, highwayman,
# Nearest to while: when, although, brun, and, rolls, but, miscellaneous, lynching,
# Nearest to used: known, required, available, found, written, held, cassation, seen,
# Nearest to after: before, during, when, despite, until, registrations, from, tagore,
# Nearest to in: during, modelled, around, throughout, within, incorporeal, at, fore,
# Nearest to some: many, several, various, these, most, any, both, other,
# Nearest to this: which, it, what, clinching, sebastian, tinbergen, leaflets, that,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Average loss at step 42000: 2.943018
# Average loss at step 44000: 2.941770
# Average loss at step 46000: 2.908242
# Average loss at step 48000: 2.869082
# Average loss at step 50000: 2.843129
# Nearest to at: shooters, in, sorceress, extending, during, entrails, polarizing, ite,
# Nearest to other: various, individual, different, espace, cultural, regionally, beheading, adhere,
# Nearest to one: two, seven, four, six, nine, eight, three, five,
# Nearest to all: both, many, several, various, every, any, some, these,
# Nearest to states: kingdom, nations, countries, rt, state, monopoly, montpellier, sculptured,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to the: its, a, their, any, your, our, vn, apartments,
# Nearest to over: auroral, through, within, secundus, subscriptions, pritchard, bankrupt, janos,
# Nearest to into: from, through, across, efficacious, oscillations, accelerates, between, under,
# Nearest to while: although, when, brun, but, like, including, rolls, lynching,
# Nearest to used: required, known, available, found, held, written, easy, seen,
# Nearest to after: before, during, when, despite, until, registrations, dekker, amex,
# Nearest to in: during, within, at, around, fore, throughout, of, webber,
# Nearest to some: many, several, these, various, any, certain, most, all,
# Nearest to this: which, it, clinching, tinbergen, what, distilling, the, that,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Average loss at step 52000: 2.885178
# Average loss at step 54000: 2.860333
# Average loss at step 56000: 2.856071
# Average loss at step 58000: 2.767719
# Average loss at step 60000: 2.828708
# Nearest to at: in, shooters, sorceress, during, entrails, extending, on, under,
# Nearest to other: various, individual, amalgam, cultural, different, adhere, regionally, espace,
# Nearest to one: two, four, seven, six, three, eight, five, nine,
# Nearest to all: both, various, several, many, these, salvage, every, llewelyn,
# Nearest to states: kingdom, nations, state, countries, rt, montpellier, matters, pflp,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to the: its, their, our, your, his, this, any, a,
# Nearest to over: auroral, through, within, secundus, between, pritchard, subscriptions, into,
# Nearest to into: from, through, across, within, between, accelerates, over, oscillations,
# Nearest to while: although, when, brun, but, encourages, after, like, lynching,
# Nearest to used: required, available, found, known, held, mentioned, written, described,
# Nearest to after: before, during, when, despite, until, registrations, taps, while,
# Nearest to in: during, within, at, on, modelled, among, throughout, fore,
# Nearest to some: many, several, various, certain, any, these, most, both,
# Nearest to this: which, it, the, clinching, tinbergen, some, distilling, archimedes,
# Nearest to seven: five, six, eight, four, nine, three, zero, two,
# Average loss at step 62000: 2.832089
# Average loss at step 64000: 2.780591
# Average loss at step 66000: 2.766464
# Average loss at step 68000: 2.720654
# Average loss at step 70000: 2.774709
# Nearest to at: sorceress, in, shooters, during, entrails, suv, epistemic, baffled,
# Nearest to other: individual, various, amalgam, different, cultural, inertial, trembling, adhere,
# Nearest to one: two, seven, five, three, six, eight, four, nine,
# Nearest to all: both, many, various, several, every, salvage, these, regensburg,
# Nearest to states: kingdom, nations, state, pflp, matters, rt, sculptured, legislation,
# Nearest to can: could, may, will, should, must, might, would, cannot,
# Nearest to the: its, their, a, his, your, any, our, each,
# Nearest to over: within, auroral, through, secundus, into, pritchard, subscriptions, between,
# Nearest to into: through, from, across, within, over, accelerates, stringing, oscillations,
# Nearest to while: although, when, however, including, after, but, undivided, lynching,
# Nearest to used: required, available, found, known, held, seen, mentioned, described,
# Nearest to after: before, during, when, despite, registrations, until, if, while,
# Nearest to in: during, within, on, at, throughout, modelled, around, fore,
# Nearest to some: many, several, various, certain, these, bidder, most, any,
# Nearest to this: which, it, tinbergen, distilling, clinching, variably, what, flinders,
# Nearest to seven: five, six, eight, nine, four, three, zero, two,
# Average loss at step 72000: 2.801597
# Average loss at step 74000: 2.660515
# Average loss at step 76000: 2.802967
# Average loss at step 78000: 2.823824
# Average loss at step 80000: 2.784756
# Nearest to at: in, during, sorceress, shooters, entrails, under, suv, extending,
# Nearest to other: individual, various, cultural, different, amalgam, whirl, inertial, federer,
# Nearest to one: two, seven, eight, nine, four, six, five, three,
# Nearest to all: both, various, many, any, several, every, salvage, some,
# Nearest to states: kingdom, nations, state, countries, pflp, monopoly, unsophisticated, rt,
# Nearest to can: could, may, will, should, might, must, cannot, would,
# Nearest to the: their, its, our, his, your, hl, any, each,
# Nearest to over: auroral, through, within, secundus, subscriptions, pritchard, missa, teamwork,
# Nearest to into: through, from, across, within, onto, towards, over, down,
# Nearest to while: although, when, brun, after, before, including, however, lynching,
# Nearest to used: required, available, known, found, mentioned, described, released, seen,
# Nearest to after: before, during, when, despite, registrations, while, until, behind,
# Nearest to in: during, within, at, throughout, on, around, near, fore,
# Nearest to some: many, several, certain, these, various, any, both, most,
# Nearest to this: which, it, clinching, some, that, what, tinbergen, distilling,
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Average loss at step 82000: 2.677490
# Average loss at step 84000: 2.774416
# Average loss at step 86000: 2.745324
# Average loss at step 88000: 2.757651
# Average loss at step 90000: 2.742611
# Nearest to at: sorceress, in, shooters, during, entrails, suv, near, within,
# Nearest to other: various, individual, different, cultural, federer, amalgam, umi, regionally,
# Nearest to one: two, six, four, eight, seven, nine, three, five,
# Nearest to all: both, various, many, some, every, any, regensburg, several,
# Nearest to states: kingdom, nations, state, countries, montpellier, monopoly, pflp, matters,
# Nearest to can: could, may, should, will, might, would, must, cannot,
# Nearest to the: its, their, our, his, ricardo, your, legis, any,
# Nearest to over: auroral, through, within, subscriptions, pritchard, secundus, stockton, teamwork,
# Nearest to into: through, from, across, within, onto, towards, off, accelerates,
# Nearest to while: although, when, though, however, brun, but, before, including,
# Nearest to used: required, known, described, available, mentioned, found, recorded, needed,
# Nearest to after: before, during, despite, when, registrations, without, behind, until,
# Nearest to in: during, within, on, throughout, around, at, through, fore,
# Nearest to some: many, several, these, various, certain, all, most, any,
# Nearest to this: which, it, what, tinbergen, some, clinching, distilling, that,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Average loss at step 92000: 2.693353
# Average loss at step 94000: 2.728298
# Average loss at step 96000: 2.711075
# Average loss at step 98000: 2.388020
# Average loss at step 100000: 2.427903
# Nearest to at: in, during, sorceress, near, shooters, entrails, suv, after,
# Nearest to other: various, individual, amalgam, different, cultural, mitochondrion, federer, umi,
# Nearest to one: two, three, six, seven, five, consecutive, nine, mayhew,
# Nearest to all: both, various, many, every, some, several, salvage, remaining,
# Nearest to states: kingdom, nations, state, monopoly, pflp, countries, legislation, ib,
# Nearest to can: could, should, will, might, may, cannot, would, must,
# Nearest to the: his, their, its, your, our, her, noll, a,
# Nearest to over: auroral, within, through, pritchard, stockton, secundus, missa, off,
# Nearest to into: through, across, within, onto, towards, from, beyond, off,
# Nearest to while: although, when, however, though, but, after, began, before,
# Nearest to used: required, known, described, found, mentioned, available, needed, defined,
# Nearest to after: before, when, during, despite, without, registrations, behind, following,
# Nearest to in: during, at, within, throughout, near, around, fore, on,
# Nearest to some: many, several, certain, various, any, these, both, all,
# Nearest to this: which, it, some, what, each, distilling, another, clinching,
# Nearest to seven: five, nine, six, eight, four, three, zero, two,

# %%
num_points = 400
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
