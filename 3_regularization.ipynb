# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3
# ------------
#
# Previously in `2_fullyconnected.ipynb`, you trained a logistic regression and a neural network model.
#
# The goal of this assignment is to explore regularization techniques.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'not_mnist_dataset/notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 1 to [0.0, 1.0, 0.0 ...], 2 to [0.0, 0.0, 1.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Introduce and tune L2 regularization for both logistic and neural network models. Remember that L2 amounts to adding a penalty on the norm of the weights to the loss. In TensorFlow, you can compute the L2 loss for a tensor `t` using `nn.l2_loss(t)`. The right amount of regularization should improve your validation / test accuracy.
#
# ---

# %%
batch_size = 128

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weights = tf.Variable(tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
      
  # Training computation.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) +
    0.001*tf.nn.l2_loss(weights) +
    0.001*tf.nn.l2_loss(biases))

  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
      print("")
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 19.080921
# Minibatch accuracy: 10.2%
# Validation accuracy: 16.2%
#
# Minibatch loss at step 500: 2.843716
# Minibatch accuracy: 78.9%
# Validation accuracy: 75.7%
#
# Minibatch loss at step 1000: 2.078385
# Minibatch accuracy: 69.5%
# Validation accuracy: 78.2%
#
# Minibatch loss at step 1500: 1.403077
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.1%
#
# Minibatch loss at step 2000: 0.932110
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.3%
#
# Minibatch loss at step 2500: 1.010997
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.8%
#
# Minibatch loss at step 3000: 0.810254
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.5%
#
# Test accuracy: 87.7%

# %%
batch_size = 128
num_neurons = 1024

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables input layer
  weights = tf.Variable(tf.truncated_normal([image_size * image_size, num_neurons]))
  biases = tf.Variable(tf.zeros([num_neurons]))
        
  # Variables output layer
  weights2 = tf.Variable(tf.truncated_normal([num_neurons, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  logits = tf.matmul(tf.nn.relu(tf.matmul(tf_train_dataset, weights) + biases), weights2) + biases2

  loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + 
    0.001*tf.nn.l2_loss(weights) +
    0.001*tf.nn.l2_loss(biases) +
    0.001*tf.nn.l2_loss(weights2) +
    0.001*tf.nn.l2_loss(biases2))
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, weights) + biases), weights2) + biases2)
  test_prediction = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, weights) + biases), weights2) + biases2)

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
      print("")
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 662.782715
# Minibatch accuracy: 12.5%
# Validation accuracy: 28.1%
#
# Minibatch loss at step 500: 206.524872
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.8%
#
# Minibatch loss at step 1000: 115.050293
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
#
# Minibatch loss at step 1500: 76.227158
# Minibatch accuracy: 68.0%
# Validation accuracy: 78.5%
#
# Minibatch loss at step 2000: 41.991096
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.8%
#
# Minibatch loss at step 2500: 25.768101
# Minibatch accuracy: 79.7%
# Validation accuracy: 85.3%
#
# Minibatch loss at step 3000: 15.567592
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.2%
#
# Test accuracy: 92.0%

# %% [markdown]
# ---
# Problem 2
# ---------
# Let's demonstrate an extreme case of overfitting. Restrict your training data to just a few batches. What happens?
#
# ---

# %%
num_steps = 200
num_batches = 3
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    #offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    offset = step % num_batches
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
      print("")
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 843.806091
# Minibatch accuracy: 5.5%
# Validation accuracy: 29.9%
#
# Test accuracy: 76.2%

# %% [markdown]
# ---
# Problem 3
# ---------
# Introduce Dropout on the hidden layer of the neural network. Remember: Dropout should only be introduced during training, not evaluation, otherwise your evaluation results would be stochastic as well. TensorFlow provides `nn.dropout()` for that, but you have to make sure it's only inserted during training.
#
# What happens to our extreme overfitting case?
#
# ---

# %%
batch_size = 128
num_neurons = 1024

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables input layer
  weights = tf.Variable(tf.truncated_normal([image_size * image_size, num_neurons]))
  biases = tf.Variable(tf.zeros([num_neurons]))
        
  # Variables output layer
  weights2 = tf.Variable(tf.truncated_normal([num_neurons, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  logits = tf.matmul(tf.nn.dropout(tf.nn.relu(tf.matmul(tf_train_dataset, weights) + biases), 0.5), weights2) + biases2
    
  loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + 
    0.001*tf.nn.l2_loss(weights) +
    0.001*tf.nn.l2_loss(biases) +
    0.001*tf.nn.l2_loss(weights2) +
    0.001*tf.nn.l2_loss(biases2))
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, weights) + biases), weights2) + biases2)
  test_prediction = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, weights) + biases), weights2) + biases2)

# %%
num_steps = 200
num_batches = 3
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    #offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    offset = step % num_batches
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
      print("")
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 794.303162
# Minibatch accuracy: 13.3%
# Validation accuracy: 33.4%
#
# Test accuracy: 76.5%

# %% [markdown]
# ---
# Problem 4
# ---------
#
# Try to get the best performance you can using a multi-layer model! The best reported test accuracy using a deep network is [97.1%](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html?showComment=1391023266211#c8758720086795711595).
#
# One avenue you can explore is to add multiple layers.
#
# Another one is to use learning rate decay:
#
#     global_step = tf.Variable(0)  # count the number of steps taken.
#     learning_rate = tf.train.exponential_decay(0.5, global_step, ...)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
#
#  ---

# %%
batch_size = 128
num_hidden_nodes1 = 1024
num_hidden_nodes2 = 256
num_hidden_nodes3 = 128
beta_regul = 0.001
keep_prob = 0.5

initial_learning_rate = 0.5
decay_steps = 4000
decay_rate = 0.65

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)
  
  # Variables.
  weights = tf.Variable(
      tf.truncated_normal([image_size * image_size, num_hidden_nodes1], stddev=np.sqrt(2.0 / (image_size * image_size))))
  biases = tf.Variable(tf.zeros([num_hidden_nodes1]))
  
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes1, num_hidden_nodes2], stddev=np.sqrt(2.0 / num_hidden_nodes1)))
  biases2 = tf.Variable(tf.zeros([num_hidden_nodes2]))
  
  weights3 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes2, num_hidden_nodes3], stddev=np.sqrt(2.0 / num_hidden_nodes2)))
  biases3 = tf.Variable(tf.zeros([num_hidden_nodes3]))
  
  weights4 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes3, num_labels], stddev=np.sqrt(2.0 / num_hidden_nodes3)))
  biases4 = tf.Variable(tf.zeros([num_labels]))
  
  
  # Training computation.
  lay1_train = tf.nn.dropout(tf.nn.relu(tf.matmul(tf_train_dataset, weights) + biases), keep_prob)
  lay2_train = tf.nn.dropout(tf.nn.relu(tf.matmul(lay1_train, weights2) + biases2), keep_prob)
  lay3_train = tf.nn.dropout(tf.nn.relu(tf.matmul(lay2_train, weights3) + biases3), keep_prob)

  logits = tf.matmul(lay3_train, weights4) + biases4
  #logits = tf.matmul(tf.nn.dropout(tf.nn.relu(tf.matmul(tf_train_dataset, weights) + biases), keep_prob), weights2) + biases2
    
  loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + 
    beta_regul * tf.nn.l2_loss(weights) +
    beta_regul * tf.nn.l2_loss(weights2) +
    beta_regul * tf.nn.l2_loss(weights3) +
    beta_regul * tf.nn.l2_loss(weights4))
  
  # Optimizer.
  learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step, decay_steps, decay_rate, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
    
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights) + biases)
  lay2_valid = tf.nn.relu(tf.matmul(lay1_valid, weights2) + biases2)
  lay3_valid = tf.nn.relu(tf.matmul(lay2_valid, weights3) + biases3)
  valid_prediction = tf.nn.softmax(tf.matmul(lay3_valid, weights4) + biases4)
  
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights) + biases)
  lay2_test = tf.nn.relu(tf.matmul(lay1_test, weights2) + biases2)
  lay3_test = tf.nn.relu(tf.matmul(lay2_test, weights3) + biases3)
  test_prediction = tf.nn.softmax(tf.matmul(lay3_test, weights4) + biases4)

# %%
num_steps = 30001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
      print("")
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.847852
# Minibatch accuracy: 14.1%
# Validation accuracy: 21.9%
#
# Minibatch loss at step 500: 1.409588
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.1%
#
# Minibatch loss at step 1000: 1.233569
# Minibatch accuracy: 78.9%
# Validation accuracy: 84.8%
#
# Minibatch loss at step 1500: 1.117654
# Minibatch accuracy: 79.7%
# Validation accuracy: 85.5%
#
# Minibatch loss at step 2000: 0.729463
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
#
# Minibatch loss at step 2500: 0.769861
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.1%
#
# Minibatch loss at step 3000: 0.870892
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.5%
#
# Minibatch loss at step 3500: 0.652780
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
#
# Minibatch loss at step 4000: 0.904280
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
#
# Minibatch loss at step 4500: 0.590452
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
#
# Minibatch loss at step 5000: 0.600112
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.5%
#
# Minibatch loss at step 5500: 0.771365
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
#
# Minibatch loss at step 6000: 0.602747
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.0%
#
# Minibatch loss at step 6500: 0.673196
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.9%
#
# Minibatch loss at step 7000: 0.827293
# Minibatch accuracy: 78.9%
# Validation accuracy: 87.7%
#
# Minibatch loss at step 7500: 0.411367
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
#
# Minibatch loss at step 8000: 0.634579
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.4%
#
# Minibatch loss at step 8500: 0.748654
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.5%
#
# Minibatch loss at step 9000: 0.597715
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.9%
#
# Minibatch loss at step 9500: 0.440144
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
#
# Minibatch loss at step 10000: 0.681783
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.6%
#
# Minibatch loss at step 10500: 0.537297
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.6%
#
# Minibatch loss at step 11000: 0.501313
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
#
# Minibatch loss at step 11500: 0.529685
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.0%
#
# Minibatch loss at step 12000: 0.565648
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.0%
#
# Minibatch loss at step 12500: 0.497454
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.5%
#
# Minibatch loss at step 13000: 0.546478
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
#
# Minibatch loss at step 13500: 0.439404
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
#
# Minibatch loss at step 14000: 0.503544
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 14500: 0.381766
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.4%
#
# Minibatch loss at step 15000: 0.524628
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 15500: 0.425057
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
#
# Minibatch loss at step 16000: 0.509493
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
#
# Minibatch loss at step 16500: 0.451080
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 17000: 0.440376
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 17500: 0.393726
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 18000: 0.560740
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 18500: 0.439427
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
#
# Minibatch loss at step 19000: 0.393620
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 19500: 0.483124
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 20000: 0.394962
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.9%
#
# Minibatch loss at step 20500: 0.411236
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 21000: 0.389647
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
#
# Minibatch loss at step 21500: 0.422658
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 22000: 0.555494
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 22500: 0.551527
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 23000: 0.489868
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.3%
#
# Minibatch loss at step 23500: 0.401873
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 24000: 0.596623
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.4%
#
# Minibatch loss at step 24500: 0.342982
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.4%
#
# Minibatch loss at step 25000: 0.452363
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 25500: 0.370016
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.4%
#
# Minibatch loss at step 26000: 0.515836
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
#
# Minibatch loss at step 26500: 0.456237
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 27000: 0.491374
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 27500: 0.364308
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.4%
#
# Minibatch loss at step 28000: 0.317609
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 28500: 0.518406
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.6%
#
# Minibatch loss at step 29000: 0.441430
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
#
# Minibatch loss at step 29500: 0.513556
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.7%
#
# Minibatch loss at step 30000: 0.366214
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
#
# Test accuracy: 95.8%

# %% [markdown]
# ### * Model accuracy 95.8%

# %%
batch_size = 128
num_hidden_nodes1 = 1024
num_hidden_nodes2 = 256
num_hidden_nodes3 = 128
beta_regul = 0.001
keep_prob = 0.5

initial_learning_rate = 0.5
decay_steps = 4000
decay_rate = 0.65

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)
  
  # Variables.
  weights = tf.Variable(
      tf.truncated_normal([image_size * image_size, num_hidden_nodes1], stddev=np.sqrt(2.0 / (image_size * image_size))))
  biases = tf.Variable(tf.zeros([num_hidden_nodes1]))
  
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes1, num_hidden_nodes2], stddev=np.sqrt(2.0 / num_hidden_nodes1)))
  biases2 = tf.Variable(tf.zeros([num_hidden_nodes2]))
  
  weights3 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes2, num_hidden_nodes3], stddev=np.sqrt(2.0 / num_hidden_nodes2)))
  biases3 = tf.Variable(tf.zeros([num_hidden_nodes3]))
  
  weights4 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes3, num_labels], stddev=np.sqrt(2.0 / num_hidden_nodes3)))
  biases4 = tf.Variable(tf.zeros([num_labels]))
  
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights) + biases)
  lay2_train = tf.nn.relu(tf.matmul(lay1_train, weights2) + biases2)
  lay3_train = tf.nn.relu(tf.matmul(lay2_train, weights3) + biases3)

  logits = tf.matmul(lay3_train, weights4) + biases4
    
  loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + 
    beta_regul * tf.nn.l2_loss(weights) +
    beta_regul * tf.nn.l2_loss(biases) +
    beta_regul * tf.nn.l2_loss(weights2) +
    beta_regul * tf.nn.l2_loss(biases2) +
    beta_regul * tf.nn.l2_loss(weights3) +
    beta_regul * tf.nn.l2_loss(biases3) +
    beta_regul * tf.nn.l2_loss(weights4) +
    beta_regul * tf.nn.l2_loss(biases4))
  
  # Optimizer.
  learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step, decay_steps, decay_rate, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
    
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights) + biases)
  lay2_valid = tf.nn.relu(tf.matmul(lay1_valid, weights2) + biases2)
  lay3_valid = tf.nn.relu(tf.matmul(lay2_valid, weights3) + biases3)
  valid_prediction = tf.nn.softmax(tf.matmul(lay3_valid, weights4) + biases4)
  
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights) + biases)
  lay2_test = tf.nn.relu(tf.matmul(lay1_test, weights2) + biases2)
  lay3_test = tf.nn.relu(tf.matmul(lay2_test, weights3) + biases3)
  test_prediction = tf.nn.softmax(tf.matmul(lay3_test, weights4) + biases4)

# %%
num_steps = 30001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
      print("")
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.403099
# Minibatch accuracy: 12.5%
# Validation accuracy: 30.9%
#
# Minibatch loss at step 500: 1.186042
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.4%
#
# Minibatch loss at step 1000: 1.010693
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.2%
#
# Minibatch loss at step 1500: 0.822783
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.4%
#
# Minibatch loss at step 2000: 0.526162
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
#
# Minibatch loss at step 2500: 0.601230
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
#
# Minibatch loss at step 3000: 0.581827
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.9%
#
# Minibatch loss at step 3500: 0.492040
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.8%
#
# Minibatch loss at step 4000: 0.595286
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.8%
#
# Minibatch loss at step 4500: 0.401451
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
#
# Minibatch loss at step 5000: 0.456165
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.8%
#
# Minibatch loss at step 5500: 0.544050
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
#
# Minibatch loss at step 6000: 0.516587
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.4%
#
# Minibatch loss at step 6500: 0.467022
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.8%
#
# Minibatch loss at step 7000: 0.562130
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.8%
#
# Minibatch loss at step 7500: 0.316136
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 8000: 0.469472
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
#
# Minibatch loss at step 8500: 0.584941
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.1%
#
# Minibatch loss at step 9000: 0.421390
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 9500: 0.348436
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
#
# Minibatch loss at step 10000: 0.538731
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.6%
#
# Minibatch loss at step 10500: 0.434070
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
#
# Minibatch loss at step 11000: 0.405419
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
#
# Minibatch loss at step 11500: 0.473305
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 12000: 0.416234
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.3%
#
# Minibatch loss at step 12500: 0.392717
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.1%
#
# Minibatch loss at step 13000: 0.415871
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.9%
#
# Minibatch loss at step 13500: 0.298581
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.3%
#
# Minibatch loss at step 14000: 0.346174
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.6%
#
# Minibatch loss at step 14500: 0.279524
# Minibatch accuracy: 97.7%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 15000: 0.466020
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 15500: 0.286524
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 16000: 0.374214
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 16500: 0.319741
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.7%
#
# Minibatch loss at step 17000: 0.287162
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.7%
#
# Minibatch loss at step 17500: 0.298656
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.9%
#
# Minibatch loss at step 18000: 0.394131
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
#
# Minibatch loss at step 18500: 0.315466
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
#
# Minibatch loss at step 19000: 0.316282
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.7%
#
# Minibatch loss at step 19500: 0.405350
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
#
# Minibatch loss at step 20000: 0.293374
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.1%
#
# Minibatch loss at step 20500: 0.285292
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.2%
#
# Minibatch loss at step 21000: 0.281929
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.9%
#
# Minibatch loss at step 21500: 0.314684
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
#
# Minibatch loss at step 22000: 0.456018
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 22500: 0.508229
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.0%
#
# Minibatch loss at step 23000: 0.359462
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.1%
#
# Minibatch loss at step 23500: 0.242176
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.2%
#
# Minibatch loss at step 24000: 0.368332
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.8%
#
# Minibatch loss at step 24500: 0.241550
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.2%
#
# Minibatch loss at step 25000: 0.307814
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.0%
#
# Minibatch loss at step 25500: 0.215773
# Minibatch accuracy: 99.2%
# Validation accuracy: 91.2%
#
# Minibatch loss at step 26000: 0.343120
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.7%
#
# Minibatch loss at step 26500: 0.331528
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 27000: 0.312575
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.2%
#
# Minibatch loss at step 27500: 0.257045
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 28000: 0.262316
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 28500: 0.331714
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.5%
#
# Minibatch loss at step 29000: 0.328637
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.4%
#
# Minibatch loss at step 29500: 0.342464
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.4%
#
# Minibatch loss at step 30000: 0.312828
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
#
# Test accuracy: 96.4%

# %% [markdown]
# ### * Model accuracy 96.4%

# %%
batch_size = 256
num_hidden_nodes1 = 1024
num_hidden_nodes2 = 256
num_hidden_nodes3 = 128
beta_regul = 0.001

initial_learning_rate = 0.5
decay_steps = 4000
decay_rate = 0.5

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)
  
  # Variables.
  weights = tf.Variable(
      tf.truncated_normal([image_size * image_size, num_hidden_nodes1], stddev=np.sqrt(2.0 / (image_size * image_size))))
  biases = tf.Variable(tf.zeros([num_hidden_nodes1]))
  
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes1, num_hidden_nodes2], stddev=np.sqrt(2.0 / num_hidden_nodes1)))
  biases2 = tf.Variable(tf.zeros([num_hidden_nodes2]))
  
  weights3 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes2, num_hidden_nodes3], stddev=np.sqrt(2.0 / num_hidden_nodes2)))
  biases3 = tf.Variable(tf.zeros([num_hidden_nodes3]))
  
  weights4 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes3, num_labels], stddev=np.sqrt(2.0 / num_hidden_nodes3)))
  biases4 = tf.Variable(tf.zeros([num_labels]))
  
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights) + biases)
  lay2_train = tf.nn.relu(tf.matmul(lay1_train, weights2) + biases2)
  lay3_train = tf.nn.relu(tf.matmul(lay2_train, weights3) + biases3)

  logits = tf.matmul(lay3_train, weights4) + biases4
    
  loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + 
    beta_regul * tf.nn.l2_loss(weights) +
    beta_regul * tf.nn.l2_loss(biases) +
    beta_regul * tf.nn.l2_loss(weights2) +
    beta_regul * tf.nn.l2_loss(biases2) +
    beta_regul * tf.nn.l2_loss(weights3) +
    beta_regul * tf.nn.l2_loss(biases3) +
    beta_regul * tf.nn.l2_loss(weights4) +
    beta_regul * tf.nn.l2_loss(biases4))
  
  # Optimizer.
  learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step, decay_steps, decay_rate, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
    
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights) + biases)
  lay2_valid = tf.nn.relu(tf.matmul(lay1_valid, weights2) + biases2)
  lay3_valid = tf.nn.relu(tf.matmul(lay2_valid, weights3) + biases3)
  valid_prediction = tf.nn.softmax(tf.matmul(lay3_valid, weights4) + biases4)
  
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights) + biases)
  lay2_test = tf.nn.relu(tf.matmul(lay1_test, weights2) + biases2)
  lay3_test = tf.nn.relu(tf.matmul(lay2_test, weights3) + biases3)
  test_prediction = tf.nn.softmax(tf.matmul(lay3_test, weights4) + biases4)

# %%
num_steps = 30001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
      print("")
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.438666
# Minibatch accuracy: 11.7%
# Validation accuracy: 36.3%
#
# Minibatch loss at step 500: 1.181835
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.4%
#
# Minibatch loss at step 1000: 0.932585
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.7%
#
# Minibatch loss at step 1500: 0.632662
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.8%
#
# Minibatch loss at step 2000: 0.656636
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
#
# Minibatch loss at step 2500: 0.582468
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.8%
#
# Minibatch loss at step 3000: 0.585939
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.0%
#
# Minibatch loss at step 3500: 0.395001
# Minibatch accuracy: 93.4%
# Validation accuracy: 89.4%
#
# Minibatch loss at step 4000: 0.414679
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 4500: 0.379915
# Minibatch accuracy: 94.1%
# Validation accuracy: 90.4%
#
# Minibatch loss at step 5000: 0.428889
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 5500: 0.343768
# Minibatch accuracy: 94.1%
# Validation accuracy: 90.4%
#
# Minibatch loss at step 6000: 0.305283
# Minibatch accuracy: 94.9%
# Validation accuracy: 90.3%
#
# Minibatch loss at step 6500: 0.371079
# Minibatch accuracy: 92.6%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 7000: 0.368489
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 7500: 0.382301
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.6%
#
# Minibatch loss at step 8000: 0.331121
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 8500: 0.395106
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
#
# Minibatch loss at step 9000: 0.330097
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
#
# Minibatch loss at step 9500: 0.405312
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.1%
#
# Minibatch loss at step 10000: 0.326509
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.1%
#
# Minibatch loss at step 10500: 0.306547
# Minibatch accuracy: 95.7%
# Validation accuracy: 90.8%
#
# Minibatch loss at step 11000: 0.293367
# Minibatch accuracy: 94.9%
# Validation accuracy: 90.9%
#
# Minibatch loss at step 11500: 0.325671
# Minibatch accuracy: 94.9%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 12000: 0.351202
# Minibatch accuracy: 94.1%
# Validation accuracy: 90.8%
#
# Minibatch loss at step 12500: 0.317888
# Minibatch accuracy: 95.7%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 13000: 0.306930
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.2%
#
# Minibatch loss at step 13500: 0.261224
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.1%
#
# Minibatch loss at step 14000: 0.351354
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.2%
#
# Minibatch loss at step 14500: 0.331073
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.0%
#
# Minibatch loss at step 15000: 0.230161
# Minibatch accuracy: 98.0%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 15500: 0.329616
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 16000: 0.346706
# Minibatch accuracy: 95.7%
# Validation accuracy: 91.2%
#
# Minibatch loss at step 16500: 0.297762
# Minibatch accuracy: 95.7%
# Validation accuracy: 91.4%
#
# Minibatch loss at step 17000: 0.276462
# Minibatch accuracy: 97.3%
# Validation accuracy: 91.7%
#
# Minibatch loss at step 17500: 0.286486
# Minibatch accuracy: 97.3%
# Validation accuracy: 91.6%
#
# Minibatch loss at step 18000: 0.280495
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 18500: 0.306055
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.4%
#
# Minibatch loss at step 19000: 0.328983
# Minibatch accuracy: 94.9%
# Validation accuracy: 91.3%
#
# Minibatch loss at step 19500: 0.307732
# Minibatch accuracy: 95.7%
# Validation accuracy: 91.6%
#
# Minibatch loss at step 20000: 0.315387
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.5%
#
# Minibatch loss at step 20500: 0.248207
# Minibatch accuracy: 97.3%
# Validation accuracy: 91.5%
#
# Minibatch loss at step 21000: 0.282587
# Minibatch accuracy: 97.3%
# Validation accuracy: 91.6%
#
# Minibatch loss at step 21500: 0.260352
# Minibatch accuracy: 96.5%
# Validation accuracy: 91.5%
#
# Minibatch loss at step 22000: 0.285132
# Minibatch accuracy: 95.7%
# Validation accuracy: 91.4%
#
# Minibatch loss at step 22500: 0.237308
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.7%
#
# Minibatch loss at step 23000: 0.270264
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.5%
#
# Minibatch loss at step 23500: 0.243179
# Minibatch accuracy: 97.3%
# Validation accuracy: 91.5%
#
# Minibatch loss at step 24000: 0.269070
# Minibatch accuracy: 96.5%
# Validation accuracy: 91.8%
#
# Minibatch loss at step 24500: 0.249490
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.6%
#
# Minibatch loss at step 25000: 0.245088
# Minibatch accuracy: 98.0%
# Validation accuracy: 91.7%
#
# Minibatch loss at step 25500: 0.262126
# Minibatch accuracy: 97.3%
# Validation accuracy: 91.4%
#
# Minibatch loss at step 26000: 0.270749
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.6%
#
# Minibatch loss at step 26500: 0.250108
# Minibatch accuracy: 98.0%
# Validation accuracy: 91.6%
#
# Minibatch loss at step 27000: 0.263724
# Minibatch accuracy: 98.8%
# Validation accuracy: 91.5%
#
# Minibatch loss at step 27500: 0.248457
# Minibatch accuracy: 98.0%
# Validation accuracy: 91.6%
#
# Minibatch loss at step 28000: 0.285667
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.7%
#
# Minibatch loss at step 28500: 0.297381
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.6%
#
# Minibatch loss at step 29000: 0.339769
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
#
# Minibatch loss at step 29500: 0.216066
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.7%
#
# Minibatch loss at step 30000: 0.236575
# Minibatch accuracy: 98.8%
# Validation accuracy: 91.7%
#
# Test accuracy: 96.5%

# %% [markdown]
# ### * Best Model accuracy 96.5%
